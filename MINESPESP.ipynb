# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.18.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'forge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2dcSspPw2mFf7AzRDqKGODwD5N1_qJpAdsimwbXBAi39FJpo" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# World		     eula.txt	    modernfix	     server.properties
# banned-ips.json      forge.jar	    mods	     user_jvm_args.txt
# banned-players.json  forge.jar.log  ops.json	     usercache.json
# colabconfig.json     journeymap     patchouli_books  usernamecache.json
# config		     libraries	    run.bat	     whitelist.json
# defaultconfigs	     logs	    run.sh
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:15775
# Estas jugando a minecraft: forge en su version: 1.18.2
# La versión de Forge es: 1.18.2-40.2.17
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.18.2-40.2.17/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [13:08:39] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 40.2.17, --fml.mcVersion, 1.18.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220404.173914]
# [13:08:39] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 9.1.3+9.1.3+main.9b69c82a starting: java version 21.0.2 by Microsoft
# [13:08:39] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2314!/ Service=ModLauncher Env=SERVER
# [13:08:40] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.18.2-40.2.17/fmlcore-1.18.2-40.2.17.jar is missing mods.toml file
# [13:08:40] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.18.2-40.2.17/javafmllanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [13:08:40] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.18.2-40.2.17/lowcodelanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [13:08:40] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.18.2-40.2.17/mclanguage-1.18.2-40.2.17.jar is missing mods.toml file
# [13:08:40] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 6 dependencies adding them to mods collection
# [13:08:43] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [13:08:43] [main/ERROR] [mixin/]: Mixin config epicsamurai.mixins.json does not specify "minVersion" property
# [13:08:43] [main/ERROR] [mixin/]: Mixin config rottencreatures-common.mixins.json does not specify "minVersion" property
# [13:08:43] [main/ERROR] [mixin/]: Mixin config rottencreatures.mixins.json does not specify "minVersion" property
# [13:08:43] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [de.maxhenkel.camera.MixinConnector]
# [13:08:43] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [13:08:43] [main/INFO] [co.ab.sa.co.Saturn/]: Loaded Saturn config file with 4 configurable options
# [13:08:43] [main/INFO] [ModernFix/]: Loaded configuration file for ModernFix 5.14.0+mc1.18.2: 74 options available, 0 override(s) found
# [13:08:43] [main/INFO] [ModernFix/]: Applying Nashorn fix
# [13:08:43] [main/INFO] [ModernFix/]: Applied Forge config corruption patch
# [13:08:43] [main/WARN] [mixin/]: Reference map 'wildbackport-forge-refmap.json' for wildbackport.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'yungsbridges.refmap.json' for yungsbridges.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'yungsbridges.refmap.json' for yungsbridges_forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'yungsextras.refmap.json' for yungsextras.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'yungsextras.refmap.json' for yungsextras_forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'arclight.mixins.refmap.json' for epicsamurai.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'creativecore.mixins.refmap.json' for creativecore.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'rottencreatures-forge-refmap.json' for rottencreatures.mixins.json could not be read. If this is a development environment you can ignore this message
# [13:08:43] [main/WARN] [mixin/]: Reference map 'coroutil.refmap.json' for coroutil.mixins.json could not be read. If this is a development environment you can ignore this message
# [Serene Seasons Transformer]: Transforming m_47480_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;Z)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming m_47519_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Successfully patched shouldSnow
# [Serene Seasons Transformer]: Transforming m_8714_ (Lnet/minecraft/world/level/chunk/LevelChunk;I)V in net/minecraft/server/level/ServerLevel
# [Serene Seasons Transformer]: Successfully patched tickChunk
# [13:08:44] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/model/geom/ModelPart (java.lang.ClassNotFoundException: net.minecraft.client.model.geom.ModelPart)
# [13:08:44] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.model.geom.ModelPart was not found wildbackport-common.mixins.json:access.ModelPartAccessor
# [13:08:44] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/renderer/RenderType for invalid dist DEDICATED_SERVER
# [13:08:44] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/RenderType (java.lang.RuntimeException: Attempted to load class net/minecraft/client/renderer/RenderType for invalid dist DEDICATED_SERVER)
# [13:08:44] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.RenderType was not found wildbackport-common.mixins.json:access.RenderTypeAccessor
# [13:08:44] [main/FATAL] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/renderer/Sheets for invalid dist DEDICATED_SERVER
# [13:08:44] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/renderer/Sheets (java.lang.RuntimeException: Attempted to load class net/minecraft/client/renderer/Sheets for invalid dist DEDICATED_SERVER)
# [13:08:44] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.renderer.Sheets was not found wildbackport-common.mixins.json:access.SheetsAccessor
# [13:08:45] [main/WARN] [mixin/]: Error loading class: net/bettercombat/client/collision/TargetFinder (java.lang.ClassNotFoundException: net.bettercombat.client.collision.TargetFinder)
# [13:08:45] [main/WARN] [mixin/]: @Mixin target net.bettercombat.client.collision.TargetFinder was not found justleveling.mixins.json:MixTargetFinder
# [13:08:45] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.2).
# [13:08:46] [main/INFO] [minecraft/Bootstrap]: ModernFix reached bootstrap stage (8.609 s after launch)
# [Serene Seasons Transformer]: Transforming m_8714_ (Lnet/minecraft/world/level/chunk/LevelChunk;I)V in net/minecraft/server/level/ServerLevel
# [Serene Seasons Transformer]: Successfully patched tickChunk
# [Serene Seasons Transformer]: Transforming m_47480_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;Z)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Patched 1 calls
# [Serene Seasons Transformer]: Transforming m_47519_ (Lnet/minecraft/world/level/LevelReader;Lnet/minecraft/core/BlockPos;)Z in net/minecraft/world/level/biome/Biome
# [Serene Seasons Transformer]: Successfully patched shouldSnow
# [13:08:47] [main/WARN] [mixin/]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [13:08:47] [main/WARN] [mixin/]: Method overwrite conflict for m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin, previously written by com.abdelaziz.saturn.mixin.leaks.biome_temperature_cache.BiomeMixin. Skipping method.
# [13:08:48] [main/INFO] [minecraft/Bootstrap]: Vanilla bootstrap took 2472 milliseconds
# [Serene Seasons Transformer]: Transforming m_8107_ ()V in net/minecraft/world/entity/animal/SnowGolem
# [Serene Seasons Transformer]: Patched 1 calls
# [13:08:49] [main/WARN] [mixin/]: @Final field f_58646_:[[Lnet/minecraft/world/effect/MobEffect; in cold_sweat.mixin.json:MixinBeaconEffects should be final
# [13:08:49] [main/WARN] [mixin/]: @Final field f_58647_:Ljava/util/Set; in cold_sweat.mixin.json:MixinBeaconEffects should be final
# [13:08:49] [main/WARN] [mixin/]: @Final field f_31427_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [13:08:49] [main/WARN] [mixin/]: @Final field f_31428_:[I in epicfight.mixins.json:MixinWitherBoss should be final
# [UnionLib Transformer]: Patching ResultSlot...
# [UnionLib Transformer]:  Successfully applied patch 1
# [UnionLib Transformer]: Patch for ResultSlot#checkTakeAchievements was successful
# [13:08:52] [modloading-worker-0/INFO] [or.in.se.SecondChanceForge/]: Second Chance: Sound Events Registered!
# [13:08:52] [modloading-worker-0/INFO] [modernworldcreation/ModernWorldCreation/]: WARNING: 'Modern World Creation' is a client mod and has no effect when loaded on a server!
# [13:08:52] [modloading-worker-0/INFO] [unionlib/]: Starting up: unionlib
# [13:08:52] [modloading-worker-0/WARN] [minecraft/SynchedEntityData]: defineId called for: class net.minecraft.world.entity.Entity from interface com.stereowalker.survive.needs.IRoastedEntity
# [13:08:53] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Successfully initialized!
# [13:08:53] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Server-side libs ready to use!
# [13:08:53] [modloading-worker-0/INFO] [CRT/]: Carrots Lib mod constructor called
# [13:08:53] [modloading-worker-0/INFO] [CR.CHANNEL/]: nextID: carrots/101
# [13:08:53] [modloading-worker-0/INFO] [CR.CHANNEL/]: nextID: carrots/102
# [13:08:53] [modloading-worker-0/INFO] [CRT/]: Potion effect neutralizer hook initialized successfully!
# [13:08:53] [modloading-worker-0/INFO] [Collective/]: Loading Collective version 7.7.
# [13:08:53] [modloading-worker-0/INFO] [CRT/]: Potion type converter hook initialized successfully!
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Attributes in class com.stereowalker.unionlib.world.entity.ai.UAttributes
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Items in class com.stereowalker.unionlib.world.item.UItems
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering MenuTypes in class com.stereowalker.unionlib.world.inventory.UMenuType
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering RecipeSerializers in class com.stereowalker.unionlib.world.item.crafting.URecipeSerializer
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Blocks in class com.stereowalker.survive.world.level.block.SBlocks
# [13:08:53] [modloading-worker-0/INFO] [CRT/]: Setting Serene Seasons mod as default season provider
# [13:08:53] [modloading-worker-0/INFO] [CRT/]: Using configured thresholds as Day-Night state provider
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Fluids in class com.stereowalker.survive.world.level.material.SFluids
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Items in class com.stereowalker.survive.world.item.SItems
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Items in class com.stereowalker.survive.world.item.HygieneItems
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering RecipeSerializers in class com.stereowalker.survive.world.item.crafting.SRecipeSerializer
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering Attributes in class com.stereowalker.survive.world.entity.ai.attributes.SAttributes
# [13:08:53] [modloading-worker-0/INFO] [UnionLib Registry/]: Registering MobEffects in class com.stereowalker.survive.world.effect.SMobEffects
# [13:08:53] [modloading-worker-0/INFO] [unionlib/]: Starting up: survive
# [13:08:53] [modloading-worker-0/INFO] [CRT/]: Registered Curios mod as primary baubles provider
# [13:08:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/Survive Configs/stamina-server.toml is not correct. Correcting
# [13:08:53] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ideal Amount Of Sleep was corrected from 6000 to its default, 6000.
# [13:08:53] [modloading-worker-0/INFO] [Spartan Weaponry/]: Constructing Mod: Spartan Weaponry
# [13:08:53] [modloading-worker-0/INFO] [Spartan Weaponry/]: Initialising API! Version: 9
# [13:08:53] [modloading-worker-0/INFO] [Spartan Weaponry/]: Spartan Weaponry API version 9 has been initalized!
# [13:08:53] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [13:08:54] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftblibrary:edit_nbt_response
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_step
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_obscuris
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:dodge_master
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:precise_roll
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:shadow_step
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:bull_charge
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:demon_mark_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:torment_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ruine_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:lunar_echo_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:satsujin_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:solar_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:charybdis
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:agony_plunge
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:true_berserk
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:plunder_perdition
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:sakura_state
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_blast
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:ender_fusion
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:basic_attack
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:air_attack
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:roll
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:step
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:knockdown_wakeup
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:demonic_ascension
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:regierung
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:lunar_eclipse
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:guard
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:solar_arcano
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:counter_attack
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:parrying
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:impact_guard
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:berserker
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:perfect_bulwark
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:death_harvest
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:emergency_escape
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:endurance
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:forbidden_strength
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:vengeful_parry
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:hypervitality
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:arrow_tenacity
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:pain_anticipation
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:stamina_pillager
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:latent_retribution
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:swordmaster
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:vampirize
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:technician
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:sweeping_edge
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:critical_knowledge
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:heart_shield
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:dancing_edge
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:mindset
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:adrenaline
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:the_guillotine
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:grasping_spire
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:heartpiercer
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:steel_whirlwind
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:dancing_blade
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill wom:meditation
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:battojutsu
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:battojutsu_passive
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:rushing_tempo
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:relentless_combo
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:liechtenauer
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:sharp_stab
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:eviscerate
# [13:08:54] [modloading-worker-0/INFO] [Dungeon Crawl/]: Here we go! Launching Dungeon Crawl 2.3.14...
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:blade_rush
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:wrathful_lighting
# [13:08:54] [modloading-worker-0/INFO] [coroutil/]: forge loader environment detected
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:tsunami
# [13:08:54] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 40.2.17, for MC 1.18.2 with MCP 20220404.173914
# [13:08:54] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v40.2.17 Initialized
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:everlasting_allegiance
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:meteor_slam
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:revelation
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:demolition_leap
# [13:08:54] [modloading-worker-0/INFO] [epicfight/]: register skill epicfight:phantom_ascent
# [13:08:54] [modloading-worker-0/INFO] [AUW/]: Armor Underwear mod constructor called
# [13:08:54] [modloading-worker-0/INFO] [AUW/]: Starting[B] DS...
# [13:08:54] [modloading-worker-0/INFO] [Spartan Shields/]: Constructing Mod: Spartan Shields
# [13:08:55] [modloading-worker-0/INFO] [th.ko.te.KotlinForForge/]: Kotlin For Forge Enabled!
# [13:08:55] [modloading-worker-0/INFO] [libIPN/]: [libIPN] libIPN - init in Kotlin
# [13:08:55] [modloading-worker-0/INFO] [be.fl.ex.ExpandAbility/]: ExpandAbility here, who dis?
# [13:08:57] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `golden_ring`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:57] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `iron_emerald_necklace`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:57] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `generic.dig_speed`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:57] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `generic.critical_rate`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:57] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `generic.critical_damage`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:57] [main/INFO] [ModernFix/]: Bypassed Mojang DFU
# [13:08:57] [main/INFO] [ModernFix/]: Instantiating Mojang DFU
# [13:08:58] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:58] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `minecraft` for name `flowing_milk`, expected `forge`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:58] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `union_inventory`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:58] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `unionlib` for name `no_remainder_crafting_shapeless`, expected `survive`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:59] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `betteroceanmonuments` for name `ocean_monument`, expected `yungsapi`. This could be a intended override, but in most cases indicates a broken mod.
# [13:08:59] [main/INFO] [ne.mi.re.GameData/]: Potentially Dangerous alternative prefix `betterfortresses` for name `fortress`, expected `yungsapi`. This could be a intended override, but in most cases indicates a broken mod.
# [13:09:00] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityLeafcutterAnt from class com.github.alexthe666.alexsmobs.entity.EntityDevilsHolePupfish
# [13:09:00] [main/WARN] [minecraft/SynchedEntityData]: defineId called for: class com.github.alexthe666.alexsmobs.entity.EntityMantisShrimp from class com.github.alexthe666.alexsmobs.entity.EntitySkelewag
# [13:09:00] [Thread-0/INFO] [ModernFix/]: Please use /mfsrc to reload any changed mod config files
# [13:09:00] [main/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/spartanweaponry-common.toml is not correct. Correcting
# [13:09:00] [main/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key traits.damage_bonus.max_armor_value was corrected from 0.0 to its default, 1.0.
# [13:09:00] [main/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/rottencreatures-common.toml is not correct. Correcting
# [13:09:00] [main/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Mob Spawns.Immortal Chance was corrected from 0.025 to its default, 0.025.
# [13:09:00] [main/INFO] [Spartan Shields/]: Loading config spartanshields-common.toml
# [13:09:01] [modloading-worker-0/INFO] [terrablender/]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [13:09:01] [modloading-worker-0/INFO] [terrablender/]: Registered region minecraft:nether to index 0 for type NETHER
# [13:09:01] [modloading-worker-0/INFO] [terrablender/]: Registered region wildbackport:overworld to index 1 for type OVERWORLD
# [13:09:01] [modloading-worker-0/INFO] [Spartan Weaponry/]: Setting up Spartan Weaponry!
# [13:09:01] [modloading-worker-0/INFO] [Dungeon Crawl/]: Common Setup
# [13:09:01] [modloading-worker-0/INFO] [AUW/]: Starting[1] DS...
# [13:09:01] [modloading-worker-0/INFO] [Spartan Shields/]: Setting up Spartan Shields!
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: BYG: "Common Setup" Event Complete!
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/end-biomes.json5" was read.
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/nether-biomes.json5" was read.
# [13:09:01] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [saturn] Starting version check at https://github.com/AbdElAziz333/Saturn/raw/mc1.20.1/dev/updates.json
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/overworld/byg-overworld-biomes.json5" was read.
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/byg-biome-dictionary.json" was read.
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/nether_surface_rules.json5" was read.
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/overworld_surface_rules.json5" was read.
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/end_surface_rules.json5" was read.
# [13:09:01] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/growing-patterns.json5" was read.
# [13:09:02] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/trades.json5" was read.
# [13:09:02] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/settings.json5" was read.
# [13:09:02] [modloading-worker-0/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/biomepedia.json5" was read.
# [13:09:02] [modloading-worker-0/INFO] [po.by.BYG/]: Created compressed zip back up for "/workspaces/codespaces-jupyter/Minecraft-server/config/byg" in "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/backups/last_working_configs_backup.zip"
# [13:09:02] [modloading-worker-0/INFO] [po.by.BYG/]: BYG: Added strippable Blocks...
# [13:09:02] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [saturn] Found status: AHEAD Current: 0.1.5 Target: null
# [13:09:02] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [secondchanceforge] Starting version check at https://infernalstudios.org/api/mods/secondchanceforge/forge
# [13:09:02] [main/INFO] [terrablender/]: Registered region biomesoplenty:overworld_common to index 2 for type OVERWORLD
# [13:09:02] [main/INFO] [terrablender/]: Registered region biomesoplenty:overworld_rare to index 3 for type OVERWORLD
# [13:09:02] [main/INFO] [terrablender/]: Registered region biomesoplenty:nether_common to index 1 for type NETHER
# [13:09:02] [main/INFO] [terrablender/]: Registered region biomesoplenty:nether_rare to index 2 for type NETHER
# [13:09:02] [main/INFO] [journeymap/]: Initializing Packet Registries
# [13:09:02] [main/INFO] [Dungeon Crawl/]: Registering Structure Piece Types
# [13:09:02] [main/INFO] [po.by.BYG/]: Initializing BYG network...
# [13:09:02] [main/INFO] [po.by.BYG/]: Initialized BYG network!
# [13:09:02] [main/INFO] [terrablender/]: Registered region byg:region_0 to index 4 for type OVERWORLD
# [13:09:02] [main/INFO] [terrablender/]: Registered region byg:region_1 to index 5 for type OVERWORLD
# [13:09:02] [main/INFO] [terrablender/]: Registered region byg:region_2 to index 6 for type OVERWORLD
# [13:09:02] [main/INFO] [terrablender/]: Registered region byg:region_3 to index 7 for type OVERWORLD
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [secondchanceforge] Found status: AHEAD Current: 1.5.0 Target: null
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [unionlib] Starting version check at https://raw.githubusercontent.com/Stereowalker/My-Home-Page/main/update_files/unionlib.json
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, LongHitAnimation wom:animmodels/animations/biped/living/biped_hit_extra_long
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_siting
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/meditation_breathing
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/agony_walk
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/agony_walk
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [unionlib] Found status: BETA Current: 7.2.4 Target: 7.1.6
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [unionlib_potionfluid] Starting version check at https://raw.githubusercontent.com/Stereowalker/My-Home-Page/main/update_files/unionlib-potions-fluids.json
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [unionlib_potionfluid] Found status: UP_TO_DATE Current: 1.0.0 Target: null
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [majruszsdifficulty] Starting version check at https://raw.githubusercontent.com/Majrusz/MinecraftCommon/main/ProgressiveDifficulty/update.json
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [majruszsdifficulty] Found status: AHEAD Current: 1.8.1 Target: null
# [13:09:03] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [carrots] Starting version check at http://jwaresoftware.org/files/mcmods/versions/carrots.json
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Sheath_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_sheathe
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Weapon_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/katana_idle
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_walk
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_walk
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_run
# [13:09:03] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/katana_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/herrscher_guard
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/herrscher_guard
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_hit
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_hit
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_parry
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/herrscher_guard_parry
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/moonless_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/moonless_run
# [13:09:04] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [carrots] Found status: UP_TO_DATE Current: 4.0 Target: null
# [13:09:04] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [camera] Starting version check at https://maxhenkel.de/update/camera.json
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/skill/moonless_guard
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_1
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_2
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, GuardAnimation wom:animmodels/animations/biped/skill/moonless_guard_hit_3
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, StaticAnimation wom:animmodels/animations/biped/living/solar_idle
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_walk
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Arm_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_R_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [13:09:04] [modloading-worker-0/WARN] [epicfight/]: [EpicFightMod] Can't find the joint Leg_L_IK in the animation file, MovementAnimation wom:animmodels/animations/biped/living/solar_run
# [13:09:04] [modloading-worker-0/INFO] [AUW/]: Starting[2] DS...
# [13:09:04] [modloading-worker-0/INFO] [co.ch.ct.ctov/]: Got IMC []
# [13:09:04] [modloading-worker-0/INFO] [AUW/]: Starting[3] DS...
# [13:09:05] [main/INFO] [po.by.BYG/]: BYG: Compostable Blocks Added!
# [13:09:05] [main/INFO] [po.by.BYG/]: BYG: Added tillables!
# [13:09:05] [main/INFO] [po.by.BYG/]: BYG: Added Flammables!
# [13:09:05] [main/INFO] [po.by.BYG/]: BYG: "Load Complete" Event Complete!
# [13:09:05] [main/WARN] [ne.mi.se.lo.ServerModLoader/LOADING]: Mods loaded with 2 warnings
# [13:09:05] [main/WARN] [ne.mi.se.lo.ServerModLoader/LOADING]: modernfix.no_lazydfu
# [13:09:05] [main/WARN] [ne.mi.se.lo.ServerModLoader/LOADING]: modernfix.perf_mod_warning
# [13:09:05] [main/INFO] [mojang/YggdrasilAuthenticationService]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [13:09:06] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23136!/assets/.mcassetsroot' uses unexpected schema
# [13:09:06] [main/WARN] [minecraft/VanillaPackResources]: Assets URL 'union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraft/server/1.18.2-20220404.173914/server-1.18.2-20220404.173914-srg.jar%23136!/data/.mcassetsroot' uses unexpected schema
# [13:09:06] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [camera] Found status: UP_TO_DATE Current: 1.18.2-1.0.6 Target: null
# [13:09:06] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [villagertools] Starting version check at https://raw.githubusercontent.com/Lothrazar/VillagerTools/trunk/1.18/update.json
# [13:09:07] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [villagertools] Found status: BETA Current: 1.18-1.0.2 Target: null
# [13:09:07] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [survive] Starting version check at https://raw.githubusercontent.com/Stereowalker/My-Home-Page/main/update_files/survive.json
# [13:09:07] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [survive] Found status: OUTDATED Current: 1.18.2-7.1.6 Target: 7.1.3
# [13:09:07] [Forge Version Check/INFO] [ne.mi.fm.VersionChecker/]: [majruszsaccessories] Starting version check at https://raw.githubusercontent.com/Majrusz/MinecraftCommon/main/Accessories/update.json
# ...
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:source_gem_samruai_chestplate_ritual as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:sculk_samruai_leggings_smithing as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:sculk_samruai_chestplate_smithing as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:brass_samruai_boots_mechanical_crafting as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:brass_samruai_leggings_mechanical_crafting as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:tyr_samurai_helmet as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Skipping loading recipe epicsamurai:source_gem_samruai_boots_ritual as it's serializer returned null
# [13:09:14] [Worker-Main-4/INFO] [minecraft/RecipeManager]: Loaded 10 recipes
# [13:09:14] [Worker-Main-4/ERROR] [minecraft/LootTables]: Couldn't parse loot table majruszsenchantments:chests/ancient_city_sixth_sense: com.google.gson.JsonSyntaxException: Unknown enchantment 'majruszsenchantments:sixth_sense'
# [13:09:15] [Worker-Main-4/INFO] [Spartan Weaponry/]: Adding Diamond Weapons to the End City Treasure Loot Table!
# [13:09:15] [Worker-Main-4/INFO] [Spartan Weaponry/]: Adding Longbow and Heavy Crossbow related loot to the Village Fletcher Loot Table!
# [13:09:15] [Worker-Main-4/INFO] [Spartan Weaponry/]: Adding Iron Weapons to the Village Weaponsmith Loot Table!
# [13:09:15] [Worker-Main-4/WARN] [minecraft/LootTables]: Found validation problem in {blocky_siege:entities/piglin_ballista}.pools[0].entries[0].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [13:09:15] [Worker-Main-4/WARN] [minecraft/LootTables]: Found validation problem in {majruszsdifficulty:undead_army/extra_mob_loot}.pools[0].functions[0]: Parameters [<parameter minecraft:killer_entity>] are not provided in this context
# [13:09:15] [Worker-Main-4/WARN] [minecraft/LootTables]: Found validation problem in {blocky_siege:entities/piglin_ballista}.pools[0].entries[1].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [13:09:15] [Worker-Main-4/INFO] [placebo/]: Registered 0 additional loot tables.
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement spartanshields:recipes/spartanshields/basic_mekanists_basic_shield: Unknown item id 'mekanism:energy_tablet'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement spartanshields:recipes/spartanshields/basic_mekanists_tower_shield: Unknown item id 'mekanism:energy_tablet'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/birch_chest_from_quark_birch_chest: Unknown item id 'quark:birch_chest'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/spruce_chest_from_quark_spruce_chest: Unknown item id 'quark:spruce_chest'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement majruszsdifficulty:progressive_difficulty/warden_treasure_bag_16: Expected item to be an item, was unknown string 'majruszsdifficulty:warden_treasure_bag'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/crimson_chest_from_quark_crimson_chest: Unknown item id 'quark:crimson_chest'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/acacia_chest_from_quark_acacia_chest: Unknown item id 'quark:acacia_chest'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/dark_oak_chest_from_quark_dark_oak_chest: Unknown item id 'quark:dark_oak_chest'
# [13:09:15] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement majruszsdifficulty:progressive_difficulty/warden_treasure_bag: Expected item to be an item, was unknown string 'majruszsdifficulty:warden_treasure_bag'
# [13:09:16] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/warped_chest_from_quark_warped_chest: Unknown item id 'quark:warped_chest'
# [13:09:16] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/jungle_chest_from_quark_jungle_chest: Unknown item id 'quark:jungle_chest'
# [13:09:16] [Worker-Main-4/ERROR] [minecraft/ServerAdvancementManager]: Parsing error loading custom advancement sophisticatedstorage:recipes/sophisticatedstorage/oak_chest_from_quark_oak_chest: Unknown item id 'quark:oak_chest'
# [13:09:16] [Worker-Main-4/INFO] [minecraft/AdvancementList]: Loaded 3296 advancements
# [13:09:16] [Worker-Main-4/INFO] [placebo/]: Registered 0 additional recipes.
# [13:09:16] [Worker-Main-4/INFO] [Dungeon Crawl/]: Loading data...
# [13:09:16] [Worker-Main-4/INFO] [Dungeon Crawl/]: Done.
# [13:09:17] [Worker-Main-4/INFO] [fastsuite/]: Successfully processed 4890 recipes into the AuxRecipeManager.
# [13:09:17] [main/INFO] [Spartan Weaponry/]: Finished initialising Weapon Traits & Attributes! Took 7.872779ms
# [13:09:17] [main/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/nether-biomes.json5" was read.
# [13:09:17] [main/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/end-biomes.json5" was read.
# [13:09:17] [Server thread/INFO] [minecraft/DedicatedServer]: Starting minecraft server version 1.18.2
# [13:09:17] [Server thread/INFO] [minecraft/DedicatedServer]: Loading properties
# [13:09:17] [Server thread/INFO] [minecraft/DedicatedServer]: Default game type: SURVIVAL
# [13:09:17] [Server thread/INFO] [minecraft/MinecraftServer]: Generating keypair
# [13:09:18] [Server thread/INFO] [minecraft/DedicatedServer]: Starting Minecraft server on *:25565
# [13:09:18] [Server thread/INFO] [minecraft/ServerConnectionListener]: Using epoll channel type
# [13:09:18] [Server thread/WARN] [minecraft/DedicatedServer]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [13:09:18] [Server thread/WARN] [minecraft/DedicatedServer]: The server will make no attempt to authenticate usernames. Beware.
# [13:09:18] [Server thread/WARN] [minecraft/DedicatedServer]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [13:09:18] [Server thread/WARN] [minecraft/DedicatedServer]: To change this, set "online-mode" to "true" in the server.properties file.
# [13:09:18] [Server thread/WARN] [minecraft/DedicatedPlayerList]: Failed to load operators list:
# com.google.gson.JsonSyntaxException: com.google.gson.stream.MalformedJsonException: Use JsonReader.setLenient(true) to accept malformed JSON at line 1 column 4 path $
# 	at com.google.gson.Gson.assertFullConsumption(Gson.java:939) ~[gson-2.8.9.jar%2321!/:?] {re:mixin}
# 	at com.google.gson.Gson.fromJson(Gson.java:902) ~[gson-2.8.9.jar%2321!/:?] {re:mixin}
# 	at net.minecraft.server.players.StoredUserList.m_11399_(StoredUserList.java:118) ~[server-1.18.2-20220404.173914-srg.jar%23136!/:?] {re:classloading}
# 	at net.minecraft.server.dedicated.DedicatedPlayerList.m_139597_(DedicatedPlayerList.java:92) ~[server-1.18.2-20220404.173914-srg.jar%23136!/:?] {re:classloading}
# 	at net.minecraft.server.dedicated.DedicatedPlayerList.<init>(DedicatedPlayerList.java:27) ~[server-1.18.2-20220404.173914-srg.jar%23136!/:?] {re:classloading}
# 	at net.minecraft.server.dedicated.DedicatedServer.m_7038_(DedicatedServer.java:167) ~[server-1.18.2-20220404.173914-srg.jar%23136!/:?] {re:computing_frames,pl:accesstransformer:B,re:classloading,pl:accesstransformer:B}
# 	at net.minecraft.server.MinecraftServer.m_130011_(MinecraftServer.java:661) ~[server-1.18.2-20220404.173914-srg.jar%23136!/:?] {re:mixin,pl:accesstransformer:B,re:computing_frames,pl:accesstransformer:B,re:classloading,pl:accesstransformer:B,pl:mixin:APP:saturn.mixins.json:allocations.server_directory.MinecraftServerMixin,pl:mixin:APP:unionlib.mixins.json:MinecraftServerMixin,pl:mixin:APP:modernfix-common.mixins.json:perf.dedicated_reload_executor.MinecraftServerMixin,pl:mixin:APP:balm.mixins.json:MinecraftServerMixin,pl:mixin:APP:byg.mixins.json:access.MinecraftServerAccess,pl:mixin:APP:byg.mixins.json:server.MixinMinecraftServer,pl:mixin:APP:vanishmod.mixins.json:gui.MinecraftServerMixin,pl:mixin:A}
# 	at net.minecraft.server.MinecraftServer.m_177918_(MinecraftServer.java:261) ~[server-1.18.2-20220404.173914-srg.jar%23136!/:?] {re:mixin,pl:accesstransformer:B,re:computing_frames,pl:accesstransformer:B,re:classloading,pl:accesstransformer:B,pl:mixin:APP:saturn.mixins.json:allocations.server_directory.MinecraftServerMixin,pl:mixin:APP:unionlib.mixins.json:MinecraftServerMixin,pl:mixin:APP:modernfix-common.mixins.json:perf.dedicated_reload_executor.MinecraftServerMixin,pl:mixin:APP:balm.mixins.json:MinecraftServerMixin,pl:mixin:APP:byg.mixins.json:access.MinecraftServerAccess,pl:mixin:APP:byg.mixins.json:server.MixinMinecraftServer,pl:mixin:APP:vanishmod.mixins.json:gui.MinecraftServerMixin,pl:mixin:A}
# 	at java.lang.Thread.run(Thread.java:1583) [?:?] {re:mixin}
# Caused by: com.google.gson.stream.MalformedJsonException: Use JsonReader.setLenient(true) to accept malformed JSON at line 1 column 4 path $
# 	at com.google.gson.stream.JsonReader.syntaxError(JsonReader.java:1562) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.stream.JsonReader.checkLenient(JsonReader.java:1403) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.stream.JsonReader.doPeek(JsonReader.java:541) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.stream.JsonReader.peek(JsonReader.java:424) ~[gson-2.8.9.jar%2321!/:?] {}
# 	at com.google.gson.Gson.assertFullConsumption(Gson.java:935) ~[gson-2.8.9.jar%2321!/:?] {re:mixin}
# 	... 8 more
# [13:09:18] [Server thread/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Configuration file ./World/serverconfig/Survive Configs/stamina-server.toml is not correct. Correcting
# [13:09:18] [Server thread/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Incorrect key Ideal Amount Of Sleep was corrected from 6000 to its default, 6000.
# [13:09:18] [Server thread/INFO] [journeymap/]: Loading JourneyMap Forge Configs
# [13:09:19] [Server thread/INFO] [spark/]: Starting background profiler...
# [13:09:20] [Server thread/INFO] [AUW/]: SetRTServer DS...
# [13:09:21] [Server thread/INFO] [terrablender/]: Initialized TerraBlender biomes for level stem minecraft:overworld
# [13:09:22] [Server thread/INFO] [minecraft/DedicatedServer]: Preparing level "World"
# [13:09:22] [Server thread/INFO] [unionlib/]: Initializing mod on server: unionlib
# [13:09:22] [Server thread/INFO] [unionlib/]: Initializing mod on server: survive
# > Field: config_button, Value: true, Config: true
# Field: config_button, Value: true, Config: true
# Resistering Temperature Queries
# Resistering Temperature Queries
# Resistering Temperature Queries
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/nether_surface_rules.json5" was read.
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/overworld_surface_rules.json5" was read.
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/end_surface_rules.json5" was read.
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: Loading dimension "minecraft:the_nether" with biome source: "byg:nether".
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/nether_surface_rules.json5" was read.
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/overworld_surface_rules.json5" was read.
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: "/workspaces/codespaces-jupyter/Minecraft-server/config/byg/surface_rules/end_surface_rules.json5" was read.
# [13:09:22] [Server thread/INFO] [po.by.BYG/]: Loading dimension "minecraft:the_end" with biome source: "byg:end".
# [13:09:22] [Server thread/INFO] [minecraft/MinecraftServer]: Preparing start region for dimension minecraft:overworld
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# > [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:27] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:28] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [13:09:28] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 38%
# [13:09:28] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 47%
# [13:09:29] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Time elapsed: 6335 ms
# [13:09:29] [Server thread/INFO] [minecraft/DedicatedServer]: Done (10.820s)! For help, type "help"
# [13:09:29] [Server thread/INFO] [ne.mi.se.pe.PermissionAPI/]: Successfully initialized permission handler forge:default_handler
# [13:09:29] [Server thread/INFO] [AUW/]: Starting[E] DS...
# [13:09:29] [Server thread/INFO] [CRT/]: Season provider and tracking is disabled (not required by any mod) [FINAL]
# [13:09:29] [Server thread/INFO] [co.gi.al.ic.IceAndFire/]: {SPAWN_DRAGON_SKELETON_I_CF=true, HYDRA_CAVE_CF=true, SPAWN_SEA_SERPENT_CF=true, SPAWN_STYMPHALIAN_BIRD_CF=true, SPAWN_WANDERING_CYCLOPS_CF=true, PIXIE_VILLAGE_CF=true, SPAWN_DEATH_WORM_CF=true, FIRE_DRAGON_CAVE_CF=true, SIREN_ISLAND_CF=true, MYRMEX_HIVE_DESERT_CF=true, SPAWN_HIPPOCAMPUS_CF=true, FIRE_DRAGON_ROOST_CF=true, MYRMEX_HIVE_JUNGLE_CF=true, COPPER_ORE_CF=true, SILVER_ORE_CF=true, LIGHTNING_DRAGON_CAVE_CF=true, SPAWN_DRAGON_SKELETON_F_CF=true, AMETHYST_ORE_CF=true, SPAWN_DRAGON_SKELETON_L_CF=true, LIGHTNING_LILY_CF=true, ICE_DRAGON_CAVE_CF=true, SAPPHIRE_ORE_CF=true, LIGHTNING_DRAGON_ROOST_CF=true, CYCLOPS_CAVE_CF=true, FROST_LILY_CF=true, FIRE_LILY_CF=true, ICE_DRAGON_ROOST_CF=true}
# [13:09:29] [Server thread/INFO] [co.gi.al.ic.IceAndFire/]: {TROLL_S=true, HIPPOGRYPH=true, AMPHITHERE=true, COCKATRICE=true, TROLL_M=true, DREAD_LICH=false, TROLL_F=true}
# [13:09:29] [Server thread/INFO] [AUW/]: Started[!] DS...
# [13:09:29] [Server thread/INFO] [patchouli/]: Sending reload packet to clients
# [13:09:29] [Server thread/WARN] [ModernFix/]: Dedicated server took 51.789 seconds to load
# >
